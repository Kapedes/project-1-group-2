# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# File to Load (Remember to Change These)
crash_data = Path("Crash_Data.csv")

# %%
crash_data_df = pd.read_csv(crash_data)

crash_data_df
# Out:
# C:\Users\theoc\AppData\Local\Temp\ipykernel_21964\3984295512.py:1: DtypeWarning: Columns (10,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   crash_data_df = pd.read_csv(crash_data)
#        Crash ID State  Month  Year    Dayweek   Time Crash Type  \
# 0      20212133   Vic      9  2021     Sunday   0:30     Single
# 1      20214022    SA      9  2021   Saturday  23:31   Multiple
# 2      20212096   Vic      9  2021   Saturday  23:00     Single
# 3      20212145   Vic      9  2021   Saturday  22:25     Single
# 4      20212075   Vic      9  2021   Saturday   5:15     Single
# ...         ...   ...    ...   ...        ...    ...        ...
# 52838  19891246   NSW      1  1989  Wednesday  17:05     Single
# 52839  19895088    WA      1  1989     Monday   6:00     Single
# 52840  19895088    WA      1  1989     Monday   6:00     Single
# 52841  19895088    WA      1  1989     Monday   6:00     Single
# ...

# %%
cleaned_crash_data_df = crash_data_df[["State", "Month", "Year", "Time", "Dayweek", "Day of week", "Time of day", "Road User", "Gender", "Age Group", "Christmas Period", "Easter Period"]]

cleaned_crash_data_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# ...

# %%
cleaned_crash_data_1_df = cleaned_crash_data_df.dropna(how="any") 

cleaned_crash_data_1_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# ...

# %%
# The following is the first dataset to use

cleaned_crash_data_1_df['State'] = cleaned_crash_data_1_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})

cleaned_crash_data_1_df
# Out:
# C:\Users\theoc\AppData\Local\Temp\ipykernel_21964\1402608149.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_crash_data_1_df['State'] = cleaned_crash_data_1_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       VIC      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       VIC      9  2021  23:00   Saturday     Weekend       Night
# 3       VIC      9  2021  22:25   Saturday     Weekend       Night
# 4       VIC      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# ...

# %%
cleaned_crash_data_2_df = crash_data_df[["State", "Month", "Year", "Time", "Dayweek", "Day of week", "Time of day", "Road User", "Gender", "Age Group", "National Road Type", "Christmas Period", "Easter Period"]]

cleaned_crash_data_2_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group National Road Type Christmas Period  \
# 0      Motorcycle rider    Male  26_to_39      Arterial Road               No
# ...

# %%
cleaned_crash_data_2_df = cleaned_crash_data_df.dropna(how="any") 

cleaned_crash_data_2_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# ...

# %%
# The following is the second dataset to use

cleaned_crash_data_2_df['State'] = cleaned_crash_data_2_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})

cleaned_crash_data_2_df
# Out:
# C:\Users\theoc\AppData\Local\Temp\ipykernel_21964\3670578941.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_crash_data_2_df['State'] = cleaned_crash_data_2_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       VIC      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       VIC      9  2021  23:00   Saturday     Weekend       Night
# 3       VIC      9  2021  22:25   Saturday     Weekend       Night
# 4       VIC      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# ...

# %%
Yearly_crashes = cleaned_crash_data_1_df.groupby(["Year"]).size()

Yearly_crashes
# Out:
# Year
# 1989    2790
# 1990    2327
# 1991    2107
# 1992    1967
# 1993    1945
# 1994    1926
# 1995    2006
# 1996    1966
# 1997    1756
# 1998    1738
# 1999    1755
# 2000    1816
# 2001    1732
# 2002    1712
# 2003    1615
# 2004    1581
# 2005    1617
# 2006    1595
# 2007    1601
# 2008    1434
# 2009    1488
# 2010    1351
# 2011    1275
# 2012    1298
# 2013    1186
# 2014    1148
# 2015    1204
# 2016    1292
# 2017    1222
# 2018    1129
# 2019    1186
# 2020    1089
# 2021     840
# dtype: int64

# %%
Years = sorted(cleaned_crash_data_1_df["Year"].unique(), reverse=False)

Years
# Out:
# [1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021]

# %%
# Create a line chart
plt.plot(Years, Yearly_crashes, marker='o', linestyle='-', color='b')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Number of Crashes')
plt.title('Crashes Over the Years')

# Display the line chart
plt.show()

# %%
Age_Group = cleaned_crash_data_2_df.groupby(['Age Group']).size()

Age_Group2 = pd.DataFrame(Age_Group)

#Renaming columns
crash_victims = Age_Group2.rename(columns={ 0: 'Fatalities'})









crash_victims
# Out:
#              Fatalities
# Age Group
# 0_to_16            4060
# 17_to_25          13753
# 26_to_39          12354
# 40_to_64          13406
# 65_to_74           4012
# 75_or_older        5109

# %%
crash_victims = cleaned_crash_data_1_df["Age Group"].value_counts()

crash_victims.plot(kind = "pie" , autopct="%1.1f%%")
plt.ylabel('Age Group')
plt.title('Crash Victims')
plt.show()

# %%
#FATAL CRASHES BY AGE GROUPS BY DRIVER NOT GROSSED BY AGE GROUP

data_driver_age = cleaned_crash_data_2_df[cleaned_crash_data_2_df['Road User'] == 'Driver']

Age_of_driver = data_driver_age.groupby('Age Group').size()

Age_of_driver.plot(kind = "pie" , autopct="%1.1f%%")
plt.ylabel('Age of Driver')
plt.title('Fatalities by Drivers by Age Group (Not normalised)')
plt.show()

# %%
#DIVIDING THE VALUES TO WHICH MOST FATALITIES OCCUR FOR DRIVERS BY AGE GROUP 
# Performing steps to divide the groups by number of ages in age group
Revised_driver_ages = pd.DataFrame(Age_of_driver)
#Renaming column fatalities
Revised_driver_ages = Revised_driver_ages.rename(columns={ 0: 'Fatalities'})
Rev_Driver_age = pd.DataFrame(Revised_driver_ages)


# Define division values for each Age Group
division_values = {
    '0_to_16': 2,
    '17_to_25': 9,
    '26_to_39': 14,
    '40_to_64': 15,
    '65_to_74': 9,
    '75_or_older': 9
}

# Divide Fatalities by the specified values for each Age Group
Rev_Driver_age['Fatalities'] = Rev_Driver_age.apply(lambda row: row['Fatalities'] / division_values[row.name], axis=1)

# Display the modified DataFrame
print(Rev_Driver_age)
# Out:
#              Fatalities
# Age Group
# 0_to_16      112.000000
# 17_to_25     719.888889
# 26_to_39     446.857143
# 40_to_64     458.866667
# 65_to_74     202.888889
# 75_or_older  235.000000

# %%
#Creating a list for to use ina  subsequent procedure
List_age_group = cleaned_crash_data_1_df['Age Group'].unique()
List_age_group.sort()
List_age_group
# Out:
# array(['0_to_16', '17_to_25', '26_to_39', '40_to_64', '65_to_74',
#        '75_or_older'], dtype=object)

# %%
Driver_Age_Fatalities = pd.DataFrame(Rev_Driver_age,index=List_age_group)

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(Driver_Age_Fatalities['Fatalities'], labels=Driver_Age_Fatalities.index, autopct='%1.1f%%', startangle=0)
plt.title('Fatalities by Drivers by Age Group (Normalised)')
plt.show()

# %%
Day_of_week = cleaned_crash_data_1_df.groupby(["Day of week"]).size()

Revised_driver_ages = pd.DataFrame(Day_of_week)
Revised_Day_of_week = Revised_driver_ages.rename(columns={ 0: 'Fatalities'})



# Define division values for each Age Group
gross_up_value = {
    'Weekday' : 5,
    'Weekend' : 2,

}

Revised_Day_of_week['Fatalities'] = Revised_Day_of_week.apply(lambda row: row['Fatalities'] / gross_up_value[row.name], axis=1)

Revised_Day_of_week
# Out:
#              Fatalities
# Day of week
# Weekday          6196.2
# Weekend         10856.5

# %%
List_day_of_week = cleaned_crash_data_1_df['Day of week'].unique()
List_day_of_week.sort()
List_day_of_week
# Out:
# array(['Weekday', 'Weekend'], dtype=object)

# %%
Revised_Day_of_week = pd.DataFrame(Revised_Day_of_week,index=List_day_of_week)

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(Revised_Day_of_week['Fatalities'], labels=Revised_Day_of_week.index, autopct='%1.1f%%', startangle=140)
plt.title('Fatalities by Drivers by Age Group (Normalised)')
plt.show()

# %%
Road_user = cleaned_crash_data_1_df.groupby(["Road User"]).size()


Road_user
# Out:
# Road User
# Driver                          23783
# Motorcycle pillion passenger      361
# Motorcycle rider                 6626
# Other/-9                           89
# Passenger                       12191
# Pedal cyclist                    1423
# Pedestrian                       8221
# dtype: int64

# %%
#create bar chart
plt.barh(Road_user.index ,Road_user, align = "center" )

#create the ticks 
plt.xticks(rotation= 90)

# Define x and y labels
plt.xlabel('Number of fatalities')
plt.ylabel('Road user fatality')
plt.title('Road user fatalities')

#Display bar chart
plt.show()

# %%
Easter_period = cleaned_crash_data_1_df.groupby(["Easter Period"]).size()
Easter_period
# Out:
# Easter Period
# No     52425
# Yes      269
# dtype: int64

# %%
Christmas_Period = cleaned_crash_data_1_df.groupby(["Christmas Period"]).size()
Christmas_Period
# Out:
# Christmas Period
# No     51067
# Yes     1627
# dtype: int64
