# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
# File to Load (Remember to Change These)
crash_data = Path("Crash_Data.csv")

# %%
crash_data_df = pd.read_csv(crash_data)

crash_data_df
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_21224\3984295512.py:1: DtypeWarning: Columns (10,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   crash_data_df = pd.read_csv(crash_data)
#        Crash ID State  Month  Year    Dayweek   Time Crash Type  \
# 0      20212133   Vic      9  2021     Sunday   0:30     Single
# 1      20214022    SA      9  2021   Saturday  23:31   Multiple
# 2      20212096   Vic      9  2021   Saturday  23:00     Single
# 3      20212145   Vic      9  2021   Saturday  22:25     Single
# 4      20212075   Vic      9  2021   Saturday   5:15     Single
# ...         ...   ...    ...   ...        ...    ...        ...
# 52838  19891246   NSW      1  1989  Wednesday  17:05     Single
# 52839  19895088    WA      1  1989     Monday   6:00     Single
# 52840  19895088    WA      1  1989     Monday   6:00     Single
# 52841  19895088    WA      1  1989     Monday   6:00     Single
# ...

# %%
cleaned_crash_data_df = crash_data_df[["State", "Month", "Year", "Time", "Dayweek", "Day of week", "Time of day", "Road User", "Gender", "Age Group", "Christmas Period", "Easter Period"]]

cleaned_crash_data_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# ...

# %%
cleaned_crash_data_1_df = cleaned_crash_data_df.dropna(how="any") 

cleaned_crash_data_1_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# ...

# %%
cleaned_crash_data_1_df['State'] = cleaned_crash_data_1_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})

cleaned_crash_data_1_df
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_21224\27259036.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_crash_data_1_df['State'] = cleaned_crash_data_1_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       VIC      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       VIC      9  2021  23:00   Saturday     Weekend       Night
# 3       VIC      9  2021  22:25   Saturday     Weekend       Night
# 4       VIC      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# ...

# %%
cleaned_crash_data_2_df = crash_data_df[["State", "Month", "Year", "Time", "Dayweek", "Day of week", "Time of day", "Road User", "Gender", "Age Group", "National Road Type", "Christmas Period", "Easter Period"]]

cleaned_crash_data_2_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group National Road Type Christmas Period  \
# 0      Motorcycle rider    Male  26_to_39      Arterial Road               No
# ...

# %%
cleaned_crash_data_2_df = cleaned_crash_data_df.dropna(how="any") 

cleaned_crash_data_2_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# ...

# %%
cleaned_crash_data_2_df['State'] = cleaned_crash_data_2_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})

cleaned_crash_data_2_df
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_21224\2667877979.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_crash_data_2_df['State'] = cleaned_crash_data_2_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       VIC      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       VIC      9  2021  23:00   Saturday     Weekend       Night
# 3       VIC      9  2021  22:25   Saturday     Weekend       Night
# 4       VIC      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# ...

# %%
cleaned_crash_data_1_df.groupby(["Dayweek"]).size()
# Out:
# Dayweek
# Friday       8639
# Monday       6090
# Saturday     9674
# Sunday       8437
# Thursday     7089
# Tuesday      6130
# Wednesday    6635
# dtype: int64

# %%
# Group by the "Dayweek" column and count the number of crashes
dayweek_crashes = cleaned_crash_data_1_df.groupby("Dayweek").size().reset_index(name='Crash Count')

# Sort the DataFrame by "Crash Count" in descending order
dayweek_crashes = dayweek_crashes.sort_values(by='Crash Count', ascending=False)

# Find the day of the week with the maximum crashes
dayweek_with_most_crashes = dayweek_crashes.iloc[0]

# Print the result
print(f"The day of the week with the most crashes is {dayweek_with_most_crashes['Dayweek']} with {dayweek_with_most_crashes['Crash Count']} crashes.")

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(dayweek_crashes['Dayweek'], dayweek_crashes['Crash Count'], color='blue')
plt.title('Number of Crashes by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Crashes')
plt.show()
# Out:
# The day of the week with the most crashes is Saturday with 9674 crashes.

# %%
cleaned_crash_data_2_df = crash_data_df[["State", "Month", "Year", "Time", "Dayweek", "Day of week", "Time of day", "Road User", "Gender", "Age Group", "National Road Type", "Christmas Period", "Easter Period"]]

cleaned_crash_data_2_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group National Road Type Christmas Period  \
# 0      Motorcycle rider    Male  26_to_39      Arterial Road               No
# ...

# %%
cleaned_crash_data_2_df['National Road Type'] = cleaned_crash_data_2_df['National Road Type'].replace({"ACCESS ROAD": "Access road", "ARTERIAL ROAD": "Arterial Road", "LOCAL ROAD": "Local Road", "NATIONAL OR STATE HIGHWAY": "National or State Highway"})

cleaned_crash_data_2_df
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_21224\1720262691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_crash_data_2_df['National Road Type'] = cleaned_crash_data_2_df['National Road Type'].replace({"ACCESS ROAD": "Access road", "ARTERIAL ROAD": "Arterial Road", "LOCAL ROAD": "Local Road", "NATIONAL OR STATE HIGHWAY": "National or State Highway"})
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# ...

# %%
#What Road type has most crashes?

grouped_data = cleaned_crash_data_2_df.groupby("National Road Type").size().reset_index(name="Count")

# The resulting DataFrame 'grouped_data' will have two columns: "National Road Type" and "Count"
print(grouped_data)
# Out:
#           National Road Type  Count
# 0                Access road    102
# 1              Arterial Road   1769
# 2                     Busway      2
# 3             Collector Road    483
# 4                 Local Road   1434
# 5  National or State Highway   2019
# 6    Pedestrian Thoroughfare      5
# 7          Sub-arterial Road   1048
# 8               Undetermined     15

# %%
# Sort the grouped data by the "Count" column in descending order
sorted_data = grouped_data.sort_values(by="Count", ascending=False)

# Get the road type with the highest count and the corresponding count
most_crashes_road_type = sorted_data.iloc[0]["National Road Type"]
most_crashes_count = sorted_data.iloc[0]["Count"]

# Print the result
print(f"The road type with the most crashes is '{most_crashes_road_type}' with {most_crashes_count} crashes.")
# Out:
# The road type with the most crashes is 'National or State Highway' with 2019 crashes.

# %%
# Analysis with bar chart
plt.figure(figsize=(10, 6))
plt.bar(sorted_data["National Road Type"], sorted_data["Count"], color='skyblue')
plt.xlabel('National Road Type')
plt.ylabel('Number of Crashes')
plt.title('Number of Crashes by National Road Type')
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()

# Display the road type with the most crashes
plt.annotate(f'Most Crashes: {most_crashes_count} crashes', 
             xy=(0.5, 0), xytext=(0, -30),
             xycoords=('axes fraction', 'figure fraction'),
             textcoords='offset points',
             size=12, ha='center', va='bottom')

# Show the plot
plt.show()
