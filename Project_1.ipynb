# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
# File to Load (Remember to Change These)
crash_data = Path("Crash_Data.csv")

# %%
crash_data_df = pd.read_csv(crash_data)

crash_data_df
# Out:
# C:\Users\royip\AppData\Local\Temp\ipykernel_8096\3984295512.py:1: DtypeWarning: Columns (10,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   crash_data_df = pd.read_csv(crash_data)
#        Crash ID State  Month  Year    Dayweek   Time Crash Type  \
# 0      20212133   Vic      9  2021     Sunday   0:30     Single
# 1      20214022    SA      9  2021   Saturday  23:31   Multiple
# 2      20212096   Vic      9  2021   Saturday  23:00     Single
# 3      20212145   Vic      9  2021   Saturday  22:25     Single
# 4      20212075   Vic      9  2021   Saturday   5:15     Single
# ...         ...   ...    ...   ...        ...    ...        ...
# 52838  19891246   NSW      1  1989  Wednesday  17:05     Single
# 52839  19895088    WA      1  1989     Monday   6:00     Single
# 52840  19895088    WA      1  1989     Monday   6:00     Single
# 52841  19895088    WA      1  1989     Monday   6:00     Single
# 52842  19896063   Tas      1  1989    Tuesday  12:40   Multiple
#
#       Bus Involvement Heavy Rigid Truck Involvement  \
# 0                 NaN                           NaN
# 1                  No                            No
# 2                 NaN                           NaN
# 3                 NaN                           NaN
# 4                 NaN                           NaN
# ...               ...                           ...
# 52838             Yes                           NaN
# 52839              No                           NaN
# 52840              No                           NaN
# 52841              No                           NaN
# 52842              No                           NaN
#
#       Articulated Truck Involvement  ... Age  National Remoteness Areas  \
# 0                               NaN  ...  38   Inner Regional Australia
# 1                                No  ...  28  Major Cities of Australia
# 2                               NaN  ...  19   Inner Regional Australia
# 3                               NaN  ...  23   Outer Regional Australia
# 4                               NaN  ...  46  Major Cities of Australia
# ...                             ...  ...  ..                        ...
# 52838                            No  ...   5                        NaN
# 52839                            No  ...  19                        NaN
# 52840                            No  ...  17                        NaN
# 52841                            No  ...  17                        NaN
# 52842                            No  ...  63                        NaN
#
#                 SA4 Name 2016  National LGA Name 2017 National Road Type  \
# 0      Melbourne - Outer East        Yarra Ranges (S)      Arterial Road
# 1            Adelaide - North            Playford (C)                NaN
# 2                        Hume         Wangaratta (RC)        Access road
# 3                        Hume         Wangaratta (RC)      Arterial Road
# 4      Melbourne - South East               Casey (C)         Local Road
# ...                       ...                     ...                ...
# 52838                     NaN                     NaN                NaN
# 52839                     NaN                     NaN                NaN
# 52840                     NaN                     NaN                NaN
# 52841                     NaN                     NaN                NaN
# 52842                     NaN                     NaN                NaN
#
#       Christmas Period Easter Period Age Group Day of week Time of day
# 0                   No            No  26_to_39     Weekend       Night
# 1                   No            No  26_to_39     Weekend       Night
# 2                   No            No  17_to_25     Weekend       Night
# 3                   No            No  17_to_25     Weekend       Night
# 4                   No            No  40_to_64     Weekend       Night
# ...                ...           ...       ...         ...         ...
# 52838               No            No   0_to_16     Weekday         Day
# 52839              Yes            No  17_to_25     Weekday         Day
# 52840              Yes            No  17_to_25     Weekday         Day
# 52841              Yes            No  17_to_25     Weekday         Day
# 52842               No            No  40_to_64     Weekday         Day
#
# [52843 rows x 23 columns]

# %%
cleaned_crash_data_df = crash_data_df[["State", "Month", "Year", "Time", "Dayweek", "Day of week", "Time of day", "Road User", "Gender", "Age Group", "Christmas Period", "Easter Period"]]

cleaned_crash_data_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# 1            Pedestrian  Female  26_to_39               No            No
# 2             Passenger    Male  17_to_25               No            No
# 3                Driver    Male  17_to_25               No            No
# 4      Motorcycle rider    Male  40_to_64               No            No
# ...                 ...     ...       ...              ...           ...
# 52838         Passenger  Female   0_to_16               No            No
# 52839         Passenger    Male  17_to_25              Yes            No
# 52840         Passenger    Male  17_to_25              Yes            No
# 52841         Passenger    Male  17_to_25              Yes            No
# 52842         Passenger  Female  40_to_64               No            No
#
# [52843 rows x 12 columns]

# %%
cleaned_crash_data_1_df = cleaned_crash_data_df.dropna(how="any") 

cleaned_crash_data_1_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# 1            Pedestrian  Female  26_to_39               No            No
# 2             Passenger    Male  17_to_25               No            No
# 3                Driver    Male  17_to_25               No            No
# 4      Motorcycle rider    Male  40_to_64               No            No
# ...                 ...     ...       ...              ...           ...
# 52838         Passenger  Female   0_to_16               No            No
# 52839         Passenger    Male  17_to_25              Yes            No
# 52840         Passenger    Male  17_to_25              Yes            No
# 52841         Passenger    Male  17_to_25              Yes            No
# 52842         Passenger  Female  40_to_64               No            No
#
# [52694 rows x 12 columns]

# %%
cleaned_crash_data_1_df['State'] = cleaned_crash_data_1_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})

cleaned_crash_data_1_df
# Out:
# C:\Users\royip\AppData\Local\Temp\ipykernel_8096\27259036.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_crash_data_1_df['State'] = cleaned_crash_data_1_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       VIC      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       VIC      9  2021  23:00   Saturday     Weekend       Night
# 3       VIC      9  2021  22:25   Saturday     Weekend       Night
# 4       VIC      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   TAS      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# 1            Pedestrian  Female  26_to_39               No            No
# 2             Passenger    Male  17_to_25               No            No
# 3                Driver    Male  17_to_25               No            No
# 4      Motorcycle rider    Male  40_to_64               No            No
# ...                 ...     ...       ...              ...           ...
# 52838         Passenger  Female   0_to_16               No            No
# 52839         Passenger    Male  17_to_25              Yes            No
# 52840         Passenger    Male  17_to_25              Yes            No
# 52841         Passenger    Male  17_to_25              Yes            No
# 52842         Passenger  Female  40_to_64               No            No
#
# [52694 rows x 12 columns]

# %%
cleaned_crash_data_2_df = crash_data_df[["State", "Month", "Year", "Time", "Dayweek", "Day of week", "Time of day", "Road User", "Gender", "Age Group", "National Road Type", "Christmas Period", "Easter Period"]]

cleaned_crash_data_2_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group National Road Type Christmas Period  \
# 0      Motorcycle rider    Male  26_to_39      Arterial Road               No
# 1            Pedestrian  Female  26_to_39                NaN               No
# 2             Passenger    Male  17_to_25        Access road               No
# 3                Driver    Male  17_to_25      Arterial Road               No
# 4      Motorcycle rider    Male  40_to_64         Local Road               No
# ...                 ...     ...       ...                ...              ...
# 52838         Passenger  Female   0_to_16                NaN               No
# 52839         Passenger    Male  17_to_25                NaN              Yes
# 52840         Passenger    Male  17_to_25                NaN              Yes
# 52841         Passenger    Male  17_to_25                NaN              Yes
# 52842         Passenger  Female  40_to_64                NaN               No
#
#       Easter Period
# 0                No
# 1                No
# 2                No
# 3                No
# 4                No
# ...             ...
# 52838            No
# 52839            No
# 52840            No
# 52841            No
# 52842            No
#
# [52843 rows x 13 columns]

# %%
cleaned_crash_data_2_df = cleaned_crash_data_df.dropna(how="any") 

cleaned_crash_data_2_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# 1            Pedestrian  Female  26_to_39               No            No
# 2             Passenger    Male  17_to_25               No            No
# 3                Driver    Male  17_to_25               No            No
# 4      Motorcycle rider    Male  40_to_64               No            No
# ...                 ...     ...       ...              ...           ...
# 52838         Passenger  Female   0_to_16               No            No
# 52839         Passenger    Male  17_to_25              Yes            No
# 52840         Passenger    Male  17_to_25              Yes            No
# 52841         Passenger    Male  17_to_25              Yes            No
# 52842         Passenger  Female  40_to_64               No            No
#
# [52694 rows x 12 columns]

# %%
cleaned_crash_data_2_df['State'] = cleaned_crash_data_2_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})

cleaned_crash_data_2_df
# Out:
# C:\Users\royip\AppData\Local\Temp\ipykernel_8096\2667877979.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_crash_data_2_df['State'] = cleaned_crash_data_2_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       VIC      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       VIC      9  2021  23:00   Saturday     Weekend       Night
# 3       VIC      9  2021  22:25   Saturday     Weekend       Night
# 4       VIC      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   TAS      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# 1            Pedestrian  Female  26_to_39               No            No
# 2             Passenger    Male  17_to_25               No            No
# 3                Driver    Male  17_to_25               No            No
# 4      Motorcycle rider    Male  40_to_64               No            No
# ...                 ...     ...       ...              ...           ...
# 52838         Passenger  Female   0_to_16               No            No
# 52839         Passenger    Male  17_to_25              Yes            No
# 52840         Passenger    Male  17_to_25              Yes            No
# 52841         Passenger    Male  17_to_25              Yes            No
# 52842         Passenger  Female  40_to_64               No            No
#
# [52694 rows x 12 columns]

# %%
cleaned_crash_data_1_df.groupby(["Dayweek"]).size()
# Out:
# Dayweek
# Friday       8639
# Monday       6090
# Saturday     9674
# Sunday       8437
# Thursday     7089
# Tuesday      6130
# Wednesday    6635
# dtype: int64

# %%
# Group by the "Dayweek" column and count the number of crashes
dayweek_crashes = cleaned_crash_data_1_df.groupby("Dayweek").size().reset_index(name='Crash Count')

# Sort the DataFrame by "Crash Count" in descending order
dayweek_crashes = dayweek_crashes.sort_values(by='Crash Count', ascending=False)

# Find the day of the week with the maximum crashes
dayweek_with_most_crashes = dayweek_crashes.iloc[0]

# Print the result
print(f"The day of the week with the most crashes is {dayweek_with_most_crashes['Dayweek']} with {dayweek_with_most_crashes['Crash Count']} crashes.")

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(dayweek_crashes['Dayweek'], dayweek_crashes['Crash Count'], color='blue')
plt.title('Number of Crashes by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Crashes')
plt.show()
# Out:
# The day of the week with the most crashes is Saturday with 9674 crashes.

# %%
cleaned_crash_data_1_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       VIC      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       VIC      9  2021  23:00   Saturday     Weekend       Night
# 3       VIC      9  2021  22:25   Saturday     Weekend       Night
# 4       VIC      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   TAS      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# 1            Pedestrian  Female  26_to_39               No            No
# 2             Passenger    Male  17_to_25               No            No
# 3                Driver    Male  17_to_25               No            No
# 4      Motorcycle rider    Male  40_to_64               No            No
# ...                 ...     ...       ...              ...           ...
# 52838         Passenger  Female   0_to_16               No            No
# 52839         Passenger    Male  17_to_25              Yes            No
# 52840         Passenger    Male  17_to_25              Yes            No
# 52841         Passenger    Male  17_to_25              Yes            No
# 52842         Passenger  Female  40_to_64               No            No
#
# [52694 rows x 12 columns]

# %%
plt.figure(figsize=(8, 8)) 

state = cleaned_crash_data_1_df["State"]

state.value_counts().plot(kind="pie", autopct="%1.1f%%")

plt.title("Percentage of Car Crashes in Different State")
plt.ylabel("State")

plt.show()

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
from scipy.stats import linregress

# %%
url = "https://countriesnow.space/api/v0.1/countries/population/cities"

# %%
population_response = requests.get(url).json()
population_response
# Out:
# {'error': False,
#  'msg': 'all cities with population',
#  'data': [{'city': 'MARIEHAMN',
#    'country': 'Åland Islands',
#    'populationCounts': [{'year': '2013',
#      'value': '11370',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '11304.5',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '11226.5',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '11156.5',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2009',
#      'value': '11064',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2008',
#      'value': '10954',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2007',
#      'value': '10863',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2000',
#      'value': '10488',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Durrës',
#    'country': 'Albania',
#    'populationCounts': [{'year': '2011',
#      'value': '113249',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'TIRANA',
#    'country': 'Albania',
#    'populationCounts': [{'year': '2011',
#      'value': '418495',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2003',
#      'value': '392863',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Annaba',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '352523',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Batna',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '246800',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Béchar',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '134523',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Bejaïa',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '144405',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Beskra',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '177060',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Bordj Bou Arreridj',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '129004',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Bordj el Kiffan',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '103690',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Ech Cheliff (El Asnam)',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '174314',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'El Boulaïda (Blida)',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '229788',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'ALGIERS (EL DJAZAIR)',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '1569897',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'El Djelfa',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '158679',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'El Eulma',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '104758',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'El Wad',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '105151',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Ghardaïa',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '127959',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Ghilizane',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '104644',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Guelma',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '108682',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Jijel',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '106306',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Lemdiyya (Medea)',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '128427',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Mestghanem (Mostaganem)',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '125911',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': "M'Sila",
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '102151',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Qacentina (Constantine)',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '465021',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Saïda',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '113533',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Sidi-bel-Abbès',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '183931',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Skikda',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '153531',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Souq Ahras',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '114512',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Stif (Sétif)',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '214842',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Tbessa',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '154335',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Tihert',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '148850',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Tilimsen (Tlemcen)',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '156258',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Touggourt',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '114183',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Wahran (Oran)',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '705335',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Wargla',
#    'country': 'Algeria',
#    'populationCounts': [{'year': '1998',
#      'value': '139381',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'PAGO PAGO',
#    'country': 'American Samoa',
#    'populationCounts': [{'year': '2010',
#      'value': '3656',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2000',
#      'value': '4278',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'ANDORRA LA VELLA',
#    'country': 'Andorra',
#    'populationCounts': [{'year': '2011',
#      'value': '22205',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '23505',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2009',
#      'value': '24779',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2008',
#      'value': '24632',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2007',
#      'value': '24574',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2006',
#      'value': '24211',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2005',
#      'value': '23587',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2003',
#      'value': '21245',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'THE VALLEY',
#    'country': 'Anguilla',
#    'populationCounts': [{'year': '2001',
#      'value': '4904',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'ST. JOHN',
#    'country': 'Antigua and Barbuda',
#    'populationCounts': [{'year': '1991',
#      'value': '22342',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Bahía Blanca-Cerri',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '317325.704982449',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '314948',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '310151',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '260096',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'BUENOS AIRES',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '13339001.6015536',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '13242375',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '13047383.5911513',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '2965403',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '11298030',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Catamarca',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '215795.389398648',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '212174',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '204865.910814638',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '109882',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '132626',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Comodoro Rivadavia-Rada Tilly',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '146557.365847925',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '145475',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '143291.153938137',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '124104',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Concordia',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '157705.748550135',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '155905',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '152271.040291904',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '116485',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Córdoba',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '1442000.64659388',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '1429922',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '1405547.38043669',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '1157507',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '1208554',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '140896',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '316032',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '328773',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '328325',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '328750',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '328603',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2009',
#      'value': '328488',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2008',
#      'value': '325453',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2006',
#      'value': '322867',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '308072',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '303874',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '412759',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Corrientes',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '373981.279268183',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '368778',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '358278.429569445',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '258103',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Formosa',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '253508.104025216',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '249062',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '240088.945193687',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '147636',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '88171',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '92023',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'La Plata',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '764468.872784661',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '757980',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '744885.526810173',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '521936',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '642979',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'La Rioja',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '193763.58807037',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '189845',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '181938.392736754',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'San Luis - El Chorrillo',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '216609.517202332',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '212154',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '203161.629153992',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Mar del Plata-Batán',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '633905.593145199',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '628672',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '618111.615502295',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '512880',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Mendoza',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '923203.297204453',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '916220',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '902127.207628422',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '121620',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '773113',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Neuquén-Plottier',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '277609.714022646',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '273503',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '265215.661375981',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '167296',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '183579',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Paraná',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '286659.493034397',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '283328',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '276605.320616689',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '207041',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '211936',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Posadas',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '312162.868950168',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '307619',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '298450.237364442',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '201273',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '210755',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Resistencia',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '406284.472613334',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '400869',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '389940.094689328',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '229212',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '292287',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Río Cuarto',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '168400.500188638',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '167057',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '164344.459035137',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '134355',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '138853',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Rosario',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '1284951.22445876',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '1277149',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '1261404.11160335',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '907718',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '1118905',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '105561',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Salta',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '562807.15066998',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '554291',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '537106.522392764',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '367550',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '370904',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'San Juan',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '486313.228956941',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '480354',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '468329.572242688',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '119423',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '352691',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '121430',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2007',
#      'value': '125338',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2000',
#      'value': '117680',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'San Salvador de Jujuy-Palpalá',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '322872.909734593',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '318287',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '309034.152094366',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '178748',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '180102',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Santa Fé',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '521233.02888211',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '516203',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '506053.768541226',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '353063',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '406388',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Santa Rosa-Toay',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '127398.589387156',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '125354',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '121229.365117479',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Santiago del Estero-La Banda',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '387320.455373139',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '381767',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '370561.386314553',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '189947',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '263471',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Tucumán-Tafí Viejo',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '836411.619309512',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '828258',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '811804.106587273',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Ushuaia-Río Grande',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2013',
#      'value': '130617.023030331',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2012',
#      'value': '127797',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '122104.906599864',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Rawson-Trelew-Playa Unión',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2012',
#      'value': '132097',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '128970.652529568',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'San Nicolás-Villa Constitución',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '2012',
#      'value': '181730',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '179757.394037044',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '119302',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Avellaneda',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '1991',
#      'value': '344024',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'General San Martín',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '1991',
#      'value': '406809',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'La Matanza',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '1991',
#      'value': '1120088',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Lanus',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '1991',
#      'value': '468561',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Lomas de Zamora',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '1991',
#      'value': '574330',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Morón',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '1991',
#      'value': '643553',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Quilmes',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '1991',
#      'value': '511234',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'San Fernando',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '1991',
#      'value': '141063',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'San Isidro',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '1991',
#      'value': '299023',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'San Miguel de Tucumán',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '1991',
#      'value': '470809',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '622324',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Vicente López',
#    'country': 'Argentina',
#    'populationCounts': [{'year': '1991',
#      'value': '289505',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Gyumri (Leninakan)',
#    'country': 'Armenia',
#    'populationCounts': [{'year': '2011',
#      'value': '121976',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2009',
#      'value': '146355',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2008',
#      'value': '146704',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2007',
#      'value': '147350',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2006',
#      'value': '148000',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2004',
#      'value': '149200',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '150917',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'YEREVAN',
#    'country': 'Armenia',
#    'populationCounts': [{'year': '2011',
#      'value': '1060138',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2009',
#      'value': '1116648',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2008',
#      'value': '1109580',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2007',
#      'value': '1106383',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2006',
#      'value': '1104398',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2004',
#      'value': '1102427',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '1103488',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Vanadzoz (Kirovakan)',
#    'country': 'Armenia',
#    'populationCounts': [{'year': '2009',
#      'value': '104825',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2008',
#      'value': '104886',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2007',
#      'value': '105100',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2006',
#      'value': '105300',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2004',
#      'value': '105900',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '107394',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'ORANJESTAD',
#    'country': 'Aruba',
#    'populationCounts': [{'year': '2010',
#      'value': '28295',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '1991',
#      'value': '20045',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Adelaide',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '1250795',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '1198468',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '1225235',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '1203186',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2009',
#      'value': '1187466',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2008',
#      'value': '1172105',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2007',
#      'value': '1158259',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2006',
#      'value': '1040717',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2006',
#      'value': '1105840',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2005',
#      'value': '1129145',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2004',
#      'value': '1123199',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2003',
#      'value': '1119097',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '1066103',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '995955',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Brisbane',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '2099328',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '1977315',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '2065996',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '2043185',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2009',
#      'value': '2004262',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2008',
#      'value': '1945639',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2007',
#      'value': '1857594',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2006',
#      'value': '1676390',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2006',
#      'value': '1763136',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2005',
#      'value': '1790921',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2004',
#      'value': '1777667',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2003',
#      'value': '1735181',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '1608820',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '1490475',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Cairns',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '142124',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '139693',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2011',
#      'value': '133911',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '150920',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2009',
#      'value': '147118',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2008',
#      'value': '142001',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2007',
#      'value': '135856',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2005',
#      'value': '123775',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2004',
#      'value': '120483',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2003',
#      'value': '117531',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '16314',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '116885',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Canberra-Queanbeyan',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '412049',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '404559',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2010',
#      'value': '410419',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'}]},
#   {'city': 'Central Coast',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '317517',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '304753',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2006',
#      'value': '282725',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '254579',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Darwin',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '116215',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '106255',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '120584',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '127532',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2009',
#      'value': '124760',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2008',
#      'value': '120652',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2007',
#      'value': '117395',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2006',
#      'value': '105994',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2005',
#      'value': '111179',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2004',
#      'value': '109432',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2003',
#      'value': '108039',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '106476',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '87662',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Geelong',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '179689',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '177023',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2011',
#      'value': '173454',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '178650',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2009',
#      'value': '175803',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2008',
#      'value': '172300',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2007',
#      'value': '169544',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2006',
#      'value': '137222',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2005',
#      'value': '165827',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2004',
#      'value': '164134',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2003',
#      'value': '162637',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '129668',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Gold Coast-Tweed Heads',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '592389',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '579909',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2011',
#      'value': '557822',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '591473',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2009',
#      'value': '577977',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2006',
#      'value': '402647',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '406619',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Greater Adelaide',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '1278432',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '1262940',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'}]},
#   {'city': 'Greater Brisbane',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '2192065',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '2146577',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'}]},
#   {'city': 'Greater Darwin',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '131938',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '129062',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'}]},
#   {'city': 'Greater Hobart',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '216981',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '216276',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'}]},
#   {'city': 'Greater Melbourne',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '4248344',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '4169103',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'}]},
#   {'city': 'Greater Perth',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '1899999',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '1832114',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'}]},
#   {'city': 'Greater Sydney',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '4672619',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '4605992',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'}]},
#   {'city': 'Hobart',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '205557',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '200501',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '211656',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '214705',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2009',
#      'value': '212019',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2008',
#      'value': '209287',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2007',
#      'value': '207484',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Provisional figure'},
#     {'year': '2006',
#      'value': '128579',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2006',
#      'value': '200525',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2005',
#      'value': '203527',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2004',
#      'value': '202182',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2003',
#      'value': '199926',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '190161',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2001',
#      'value': '125162',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Melbourne',
#    'country': 'Australia',
#    'populationCounts': [{'year': '2012',
#      'value': '4086734',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '3847570',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2011',
#      'value': '3999982',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'},
#     {'year': '2010',
#      'value': '4077036',
# ...
#      'value': '1938510',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Linzhou',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '982254',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Lishi',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '235678',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Lishui',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '348241',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': "Lu'an",
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1559037',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Liupanshui',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '995055',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Liuyang',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1307572',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Liuzhou',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1220392',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Liyang',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '740871',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Longhai',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '816318',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Longjing',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '261551',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Longkou',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '671335',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Longquan',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '250398',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Longyan',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '543731',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Loudi',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '398577',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Lucheng',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '213944',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Lufeng',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1164767',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Luoding',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '866190',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Luohe',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '304105',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Luoyang',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1491680',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Luquan',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '397449',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Luxi (Yunnan)',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '337406',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Luzhou',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1252884',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': "Ma'anshan",
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '567576',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Macheng',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1129047',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Manzhouli',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '181112',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Maoming',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '644301',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Meihekou',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '617674',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Meishan',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '799309',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Meizhou',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '354302',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Mianyang',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1162962',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Mianzhu',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '515830',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Miluo',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '658867',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Mingguang',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '569585',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Miquan',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '180952',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Mishan',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '438277',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Mudanjiang',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1014206',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Muling',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '310096',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Nanan',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1385276',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Nanchang',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1844253',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Nanchong',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1771920',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Nanchuan',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '631853',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Nangong',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '467356',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Nanhai',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '2133741',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Nanjing',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '3624234',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Nankang',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '694987',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Nanning',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1766701',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Nanping',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '488818',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Nantong',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '771386',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Nanxiong',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '372844',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Nanyang',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1584715',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Nehe',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '672295',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Neijiang',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1391931',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Ningan',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '437328',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Ningbo',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1567499',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Ningde',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '400293',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Ningguo',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '381842',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Panjin',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '602541',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Panshi',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '530470',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Panzhihua',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '690739',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Penglai',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '500408',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Pengzhou',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '770749',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Pingdingshan',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '900903',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Pingdu',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1321975',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Pinghu',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '507899',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Pingliang',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '454996',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Pingxiang (Guangxi)',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '107046',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Pingxiang (Jiangxi)',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '783445',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Pizhou',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1539922',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Pulandian',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '757844',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Puning',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1856402',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Putian',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '443926',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Puyang',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '448290',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Qianan',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '632704',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Qianjiang',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '992438',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Qidong',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1057073',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Qingdao',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '2720972',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Qingtongxia',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '248640',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Qingyuan',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '506680',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Qingzhen',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '471305',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Qingzhou',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '894468',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Qinhuangdao',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '817487',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Qinyang',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '446404',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Qinzhou',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '1035504',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Qionghai',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '449845',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Qionglai',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '631577',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   {'city': 'Qiongshan',
#    'country': 'China',
#    'populationCounts': [{'year': '2000',
#      'value': '678149',
#      'sex': 'Both Sexes',
#      'reliabilty': 'Final figure, complete'}]},
#   ...]}

# %%
import requests
# List of Australian capital cities
australian_capital_cities = [
    'Canberra',
    'Sydney',
    'Melbourne',
    'Brisbane',
    'Perth',
    'Adelaide',
    'Hobart',
    'Darwin'
]
api_key = '5IH57hzwqSIQmrImk36cGQ==NGbyGLNFBZspuamr' #make a new doc to hide API Key, this is just to test it works
base_url = 'https://api.api-ninjas.com/v1/city?name={}'
for city in australian_capital_cities:
    api_url = base_url.format(city)
    response = requests.get(api_url, headers={'X-Api-Key': api_key})
    if response.status_code == requests.codes.ok:
        data = response.json()  # Assuming the response is in JSON format
        if data and isinstance(data, list) and len(data) > 0:
            city_data = data[0]  # Get the first item in the response
            population = city_data.get('population', 'Population data not available')
            print(f"{city}: Population - {population}")
        else:
            print(f"No data available for {city}")
    else:
        print(f"Error fetching data for {city}: {response.status_code} - {response.text}")
# Out:
# Canberra: Population - 426704
# Sydney: Population - 5312163
# Melbourne: Population - 5078193
# Brisbane: Population - 2514184
# Perth: Population - 2059484
# Adelaide: Population - 1345777
# Hobart: Population - 240342
# Darwin: Population - 136828
