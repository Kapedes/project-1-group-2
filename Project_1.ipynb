# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# File to Load (Remember to Change These)
crash_data = Path("Crash_Data.csv")

# %%
crash_data_df = pd.read_csv(crash_data)

crash_data_df
# Out:
# C:\Users\royip\AppData\Local\Temp\ipykernel_14888\3984295512.py:1: DtypeWarning: Columns (10,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   crash_data_df = pd.read_csv(crash_data)
#        Crash ID State  Month  Year    Dayweek   Time Crash Type  \
# 0      20212133   Vic      9  2021     Sunday   0:30     Single
# 1      20214022    SA      9  2021   Saturday  23:31   Multiple
# 2      20212096   Vic      9  2021   Saturday  23:00     Single
# 3      20212145   Vic      9  2021   Saturday  22:25     Single
# 4      20212075   Vic      9  2021   Saturday   5:15     Single
# ...         ...   ...    ...   ...        ...    ...        ...
# 52838  19891246   NSW      1  1989  Wednesday  17:05     Single
# 52839  19895088    WA      1  1989     Monday   6:00     Single
# 52840  19895088    WA      1  1989     Monday   6:00     Single
# 52841  19895088    WA      1  1989     Monday   6:00     Single
# ...

# %%
cleaned_crash_data_df = crash_data_df[["State", "Month", "Year", "Time", "Dayweek", "Day of week", "Time of day", "Road User", "Gender", "Age Group", "Christmas Period", "Easter Period"]]

cleaned_crash_data_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# ...

# %%
cleaned_crash_data_1_df = cleaned_crash_data_df.dropna(how="any") 

cleaned_crash_data_1_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# ...

# %%
# The following is the first dataset to use

cleaned_crash_data_1_df['State'] = cleaned_crash_data_1_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})

cleaned_crash_data_1_df
# Out:
# C:\Users\royip\AppData\Local\Temp\ipykernel_14888\1402608149.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_crash_data_1_df['State'] = cleaned_crash_data_1_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       VIC      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       VIC      9  2021  23:00   Saturday     Weekend       Night
# 3       VIC      9  2021  22:25   Saturday     Weekend       Night
# 4       VIC      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# ...

# %%
cleaned_crash_data_2_df = crash_data_df[["State", "Month", "Year", "Time", "Dayweek", "Day of week", "Time of day", "Road User", "Gender", "Age Group", "National Road Type", "Christmas Period", "Easter Period"]]

cleaned_crash_data_2_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group National Road Type Christmas Period  \
# 0      Motorcycle rider    Male  26_to_39      Arterial Road               No
# ...

# %%
cleaned_crash_data_2_df = cleaned_crash_data_df.dropna(how="any") 

cleaned_crash_data_2_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# ...

# %%
# The following is the second dataset to use

cleaned_crash_data_2_df['State'] = cleaned_crash_data_2_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})

cleaned_crash_data_2_df
# Out:
# C:\Users\royip\AppData\Local\Temp\ipykernel_14888\3670578941.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_crash_data_2_df['State'] = cleaned_crash_data_2_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       VIC      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       VIC      9  2021  23:00   Saturday     Weekend       Night
# 3       VIC      9  2021  22:25   Saturday     Weekend       Night
# 4       VIC      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# ...

# %%
cleaned_crash_data_3_df = crash_data_df[[ "National Road Type"]]
National_Road_df = cleaned_crash_data_3_df.dropna(how="any") 
National_Road_df['National Road Type'] = National_Road_df['National Road Type'].replace({"NATIONAL OR STATE HIGHWAY": "National or State Highway", "ARTERIAL ROAD": "Arterial Road", "ACCESS ROAD": "Access road",  "LOCAL ROAD": "Local Road", "Undetermined": "Other" , "Pedestrian Thoroughfare": "Other" , "Busway" : "Other" ,})
National_Road_df
# Out:
# C:\Users\theoc\AppData\Local\Temp\ipykernel_4104\31695146.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   National_Road_df['National Road Type'] = National_Road_df['National Road Type'].replace({"NATIONAL OR STATE HIGHWAY": "National or State Highway", "ARTERIAL ROAD": "Arterial Road", "ACCESS ROAD": "Access road",  "LOCAL ROAD": "Local Road", "Undetermined": "Other" , "Pedestrian Thoroughfare": "Other" , "Busway" : "Other" ,})
#              National Road Type
# 0                 Arterial Road
# 2                   Access road
# 3                 Arterial Road
# 4                    Local Road
# 5                         Other
# ...                         ...
# 9091  National or State Highway
# 9097  National or State Highway
# ...

# %%
# Calculating the fatalities from road types
Road_type = National_Road_df.groupby(["National Road Type"]).size()

#Creating a dataframe
Road_type2 = pd.DataFrame(Road_type)

#Renaming column
Road_type_final = Road_type2.rename(columns={ 0: 'Fatalities'})

#Sort values
Road_type_final = Road_type_final.sort_values(by='Fatalities', ascending=True)

#Fatalities by road type 
Road_type_final
# Out:
#                            Fatalities
# National Road Type
# Other                              22
# Access road                       102
# Collector Road                    483
# Sub-arterial Road                1048
# Local Road                       1434
# Arterial Road                    1769
# National or State Highway        2019

# %%
#Fatalities by road type (creating a list)
Road_type_list = National_Road_df["National Road Type"].unique()
Road_type_list.sort()
Road_type_list
# Out:
# array(['Access road', 'Arterial Road', 'Collector Road', 'Local Road',
#        'National or State Highway', 'Other', 'Sub-arterial Road'],
#       dtype=object)

# %%
#create bar chart
plt.barh(Road_type_final.index ,Road_type_list, align = "center", color = "skyblue")

#create the ticks 
plt.xticks(rotation= 45)

# Define x and y labels
plt.xlabel('Road Type')
plt.ylabel('Number of fatalities')
plt.title('Road type fatalities')

#Display bar chart
plt.show()

# %%
Yearly_crashes = cleaned_crash_data_1_df.groupby(["Year"]).size()

Yearly_crashes2 = pd.DataFrame(Yearly_crashes)

Yearly_crashes3 = Yearly_crashes2.rename(columns={ 0: 'Fatalities'})

Yearly_crashes3
# Out:
#       Fatalities
# Year
# 1989        2790
# 1990        2327
# 1991        2107
# 1992        1967
# 1993        1945
# 1994        1926
# 1995        2006
# 1996        1966
# 1997        1756
# 1998        1738
# 1999        1755
# 2000        1816
# 2001        1732
# 2002        1712
# 2003        1615
# 2004        1581
# 2005        1617
# 2006        1595
# 2007        1601
# 2008        1434
# 2009        1488
# 2010        1351
# 2011        1275
# 2012        1298
# 2013        1186
# 2014        1148
# 2015        1204
# 2016        1292
# 2017        1222
# 2018        1129
# 2019        1186
# 2020        1089
# 2021         840

# %%
Years1 = sorted(cleaned_crash_data_1_df["Year"].unique(), reverse=False)

Years1
# Out:
# [1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021]

# %%
# Create a line chart
plt.plot(Years1, Yearly_crashes, marker='o', linestyle='-', color='b')

# Add labels and title
plt.xlabel('Years')
plt.ylabel('Number of fatalities from crashes')
plt.title('Number of fatalities from crashes between 1989 to 2021')

# Display the line chart
plt.show()

# %%
#Obtaining the number of fatalities by age group

Age_Group = cleaned_crash_data_2_df.groupby(['Age Group']).size()
# Placing into dataframe
Age_Group2 = pd.DataFrame(Age_Group)

#Renaming columns
crash_victims = Age_Group2.rename(columns={ 0: 'Fatalities'})

crash_victims
# Out:
#              Fatalities
# Age Group
# 0_to_16            4060
# 17_to_25          13753
# 26_to_39          12354
# 40_to_64          13406
# 65_to_74           4012
# 75_or_older        5109

# %%
cleaned_crash_data_1_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       VIC      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       VIC      9  2021  23:00   Saturday     Weekend       Night
# 3       VIC      9  2021  22:25   Saturday     Weekend       Night
# 4       VIC      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   TAS      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# ...

# %%
plt.figure(figsize=(8, 8))

road_user_type = cleaned_crash_data_1_df["Road User"]

road_user_count = road_user_type.value_counts()

smallest_road_users = road_user_count.nsmallest(2).index

road_user_type_grouped = road_user_type.replace(smallest_road_users, 'Other')

road_user_type_grouped.value_counts().plot(kind="pie" , autopct="%1.1f%%")

plt.ylabel("Road User")
plt.title("Types of Road User Involved in the Crash")
# Out:
# Text(0.5, 1.0, 'Types of Road User Involved in the Crash')

# %%
plt.figure(figsize=(8, 8))

state = cleaned_crash_data_1_df["State"]

state.value_counts().plot(kind="pie" , autopct="%1.1f%%")

plt.ylabel("State")
plt.title("Percentage of Crashes in Different States")
# Out:
# Text(0.5, 1.0, 'Percentage of Crashes in Different States')
