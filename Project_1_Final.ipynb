# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# File to Load (Remember to Change These)
crash_data = Path("Crash_Data.csv")

# Import the API key
from config import api_key

# %%
crash_data_df = pd.read_csv(crash_data)

crash_data_df
# Out:
# C:\Users\theoc\AppData\Local\Temp\ipykernel_1212\3984295512.py:1: DtypeWarning: Columns (10,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   crash_data_df = pd.read_csv(crash_data)
#        Crash ID State  Month  Year    Dayweek   Time Crash Type  \
# 0      20212133   Vic      9  2021     Sunday   0:30     Single
# 1      20214022    SA      9  2021   Saturday  23:31   Multiple
# 2      20212096   Vic      9  2021   Saturday  23:00     Single
# 3      20212145   Vic      9  2021   Saturday  22:25     Single
# 4      20212075   Vic      9  2021   Saturday   5:15     Single
# ...         ...   ...    ...   ...        ...    ...        ...
# 52838  19891246   NSW      1  1989  Wednesday  17:05     Single
# 52839  19895088    WA      1  1989     Monday   6:00     Single
# 52840  19895088    WA      1  1989     Monday   6:00     Single
# 52841  19895088    WA      1  1989     Monday   6:00     Single
# ...

# %%
#Choosing data fields
cleaned_crash_data_df = crash_data_df[["State", "Month", "Year", "Time", "Dayweek", "Day of week", "Time of day", "Road User", "Gender", "Age Group", "Christmas Period", "Easter Period"]]
cleaned_crash_data_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# ...

# %%
#Dropping Na's

cleaned_crash_data_1_df = cleaned_crash_data_df.dropna(how="any") 

cleaned_crash_data_1_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# ...

# %%
#Replacing state names

cleaned_crash_data_1_df['State'] = cleaned_crash_data_1_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})

cleaned_crash_data_1_df
# Out:
# C:\Users\theoc\AppData\Local\Temp\ipykernel_1212\609134707.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_crash_data_1_df['State'] = cleaned_crash_data_1_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       VIC      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       VIC      9  2021  23:00   Saturday     Weekend       Night
# 3       VIC      9  2021  22:25   Saturday     Weekend       Night
# 4       VIC      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# ...

# %%
#dataset 2 used
cleaned_crash_data_2_df = crash_data_df[["State", "Month", "Year", "Time", "Dayweek", "Day of week", "Time of day", "Road User", "Gender", "Age Group", "National Road Type", "Christmas Period", "Easter Period"]]

cleaned_crash_data_2_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group National Road Type Christmas Period  \
# 0      Motorcycle rider    Male  26_to_39      Arterial Road               No
# ...

# %%
# Dataset 2 with dropped Na's 

cleaned_crash_data_2_df = cleaned_crash_data_df.dropna(how="any") 

cleaned_crash_data_2_df
# Out:
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       Vic      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       Vic      9  2021  23:00   Saturday     Weekend       Night
# 3       Vic      9  2021  22:25   Saturday     Weekend       Night
# 4       Vic      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# 52838   NSW      1  1989  17:05  Wednesday     Weekday         Day
# 52839    WA      1  1989   6:00     Monday     Weekday         Day
# 52840    WA      1  1989   6:00     Monday     Weekday         Day
# 52841    WA      1  1989   6:00     Monday     Weekday         Day
# 52842   Tas      1  1989  12:40    Tuesday     Weekday         Day
#
#               Road User  Gender Age Group Christmas Period Easter Period
# 0      Motorcycle rider    Male  26_to_39               No            No
# ...

# %%
#Dataset 2 changed names
cleaned_crash_data_2_df['State'] = cleaned_crash_data_2_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})

cleaned_crash_data_2_df
# Out:
# C:\Users\theoc\AppData\Local\Temp\ipykernel_1212\3657649164.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_crash_data_2_df['State'] = cleaned_crash_data_2_df['State'].replace({"Vic": "VIC", "Qld": "QLD", "Tas": "TAS"})
#       State  Month  Year   Time    Dayweek Day of week Time of day  \
# 0       VIC      9  2021   0:30     Sunday     Weekend       Night
# 1        SA      9  2021  23:31   Saturday     Weekend       Night
# 2       VIC      9  2021  23:00   Saturday     Weekend       Night
# 3       VIC      9  2021  22:25   Saturday     Weekend       Night
# 4       VIC      9  2021   5:15   Saturday     Weekend       Night
# ...     ...    ...   ...    ...        ...         ...         ...
# ...

# %%
#Day of the week by size 
cleaned_crash_data_1_df.groupby(["Dayweek"]).size()
# Out:
# Dayweek
# Friday       8639
# Monday       6090
# Saturday     9674
# Sunday       8437
# Thursday     7089
# Tuesday      6130
# Wednesday    6635
# dtype: int64

# %%
#National road df

National_Road_df = crash_data_df[['National Road Type']]

National_Road_df
# Out:
#       National Road Type
# 0          Arterial Road
# 1                    NaN
# 2            Access road
# 3          Arterial Road
# 4             Local Road
# ...                  ...
# 52838                NaN
# 52839                NaN
# 52840                NaN
# 52841                NaN
# 52842                NaN
#
# [52843 rows x 1 columns]

# %%
#Changing names for the National roads df

National_Road_df1 = National_Road_df.dropna(how="any") 
National_Road_df1['National Road Type'] = National_Road_df1['National Road Type'].replace({"ACCESS ROAD": "Access road", "NATIONAL OR STATE HIGHWAY": "National or State Highway", "ARTERIAL ROAD": "Arterial Road", "LOCAL ROAD": "Local Road", "Busway": "Other", "Undetermined": "Other", "Pedestrian Thoroughfare": "Other"})
National_Road_df1
# Out:
# C:\Users\theoc\AppData\Local\Temp\ipykernel_1212\2786668092.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   National_Road_df1['National Road Type'] = National_Road_df1['National Road Type'].replace({"ACCESS ROAD": "Access road", "NATIONAL OR STATE HIGHWAY": "National or State Highway", "ARTERIAL ROAD": "Arterial Road", "LOCAL ROAD": "Local Road", "Busway": "Other", "Undetermined": "Other", "Pedestrian Thoroughfare": "Other"})
#              National Road Type
# 0                 Arterial Road
# 2                   Access road
# 3                 Arterial Road
# 4                    Local Road
# 5                         Other
# ...                         ...
# 9091  National or State Highway
# 9097  National or State Highway
# ...

# %%
# Calculating the fatalities from road types
Road_type2 = National_Road_df1.groupby(["National Road Type"]).size()




#Sort values
Road_type_final = Road_type2.sort_values(ascending=True)

#Fatalities by road type 
Road_type_final
# Out:
# National Road Type
# Other                          22
# Access road                   102
# Collector Road                483
# Sub-arterial Road            1048
# Local Road                   1434
# Arterial Road                1769
# National or State Highway    2019
# dtype: int64

# %%
#Fatalities by road type (creating a list)
Road_type_list = National_Road_df1["National Road Type"].unique()
Road_type_list.sort()
Road_type_list
# Out:
# array(['Access road', 'Arterial Road', 'Collector Road', 'Local Road',
#        'National or State Highway', 'Other', 'Sub-arterial Road'],
#       dtype=object)

# %%
#create bar chart
plt.barh(Road_type_final.index ,Road_type_final, align = "center", color = "skyblue")

#create the ticks 
plt.xticks(rotation= 45)

# Define x and y labels
plt.xlabel('Number of fatalities')
plt.ylabel('Road Type')
plt.title('Fatalities by Road Type')

#Display bar chart
plt.show()

# %%
# Yearly crashes by size
Yearly_crashes = cleaned_crash_data_1_df.groupby(["Year"]).size()
#Dataframe
Yearly_crashes2 = pd.DataFrame(Yearly_crashes)
#Renaming second column fatalities
Yearly_crashes3 = Yearly_crashes2.rename(columns={ 0: 'Fatalities'})

Yearly_crashes3
# Out:
#       Fatalities
# Year
# 1989        2790
# 1990        2327
# 1991        2107
# 1992        1967
# 1993        1945
# 1994        1926
# 1995        2006
# 1996        1966
# 1997        1756
# 1998        1738
# 1999        1755
# 2000        1816
# 2001        1732
# 2002        1712
# 2003        1615
# 2004        1581
# 2005        1617
# 2006        1595
# 2007        1601
# 2008        1434
# 2009        1488
# 2010        1351
# 2011        1275
# 2012        1298
# 2013        1186
# 2014        1148
# 2015        1204
# 2016        1292
# 2017        1222
# 2018        1129
# 2019        1186
# 2020        1089
# 2021         840

# %%
#Generating a list

Years1 = sorted(cleaned_crash_data_1_df["Year"].unique(), reverse=False)

Years1
# Out:
# [1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021]

# %%
# Create a line chart
plt.plot(Years1, Yearly_crashes, marker='o', linestyle='-', color='b')

# Add labels and title
plt.xlabel('Years')
plt.ylabel('Number of fatalities from crashes')
plt.title('Number of fatalities from crashes between 1989 to 2021')

# Display the line chart
plt.show()

# %%
#Obtaining the number of fatalities by age group

Age_Group = cleaned_crash_data_2_df.groupby(['Age Group']).size()
# Placing into dataframe
Age_Group2 = pd.DataFrame(Age_Group)

#Renaming columns
crash_victims = Age_Group2.rename(columns={ 0: 'Fatalities'})

crash_victims
# Out:
#              Fatalities
# Age Group
# 0_to_16            4060
# 17_to_25          13753
# 26_to_39          12354
# 40_to_64          13406
# 65_to_74           4012
# 75_or_older        5109

# %%
#Crash victims by age in a pie chart

crash_victims = cleaned_crash_data_1_df["Age Group"].value_counts()

crash_victims.plot(kind = "pie" , autopct="%1.1f%%")
plt.ylabel('Age Group')
plt.title('Crash Victims')
plt.show()

# %%
#FATAL CRASHES BY AGE GROUPS BY DRIVER NOT GROSSED BY AGE GROUP

data_driver_age = cleaned_crash_data_2_df[cleaned_crash_data_2_df['Road User'] == 'Driver']

Age_of_driver = data_driver_age.groupby('Age Group').size()

Age_of_driver.plot(kind = "pie" , autopct="%1.1f%%")
plt.ylabel('Age of Driver')
plt.title('Fatalities by Drivers by Age Group (Not normalised)')
plt.show()

# %%
#DIVIDING THE VALUES TO WHICH MOST FATALITIES OCCUR FOR DRIVERS BY AGE GROUP 
# Performing steps to divide the groups by number of ages in age group
Revised_driver_ages = pd.DataFrame(Age_of_driver)
#Renaming column fatalities
Revised_driver_ages = Revised_driver_ages.rename(columns={ 0: 'Fatalities'})
Rev_Driver_age = pd.DataFrame(Revised_driver_ages)


# Define division values for each Age Group
division_values = {
    '0_to_16': 3,
    '17_to_25': 9,
    '26_to_39': 14,
    '40_to_64': 15,
    '65_to_74': 9,
    '75_or_older': 18
}

# Divide Fatalities by the specified values for each Age Group
Rev_Driver_age['Fatalities'] = Rev_Driver_age.apply(lambda row: row['Fatalities'] / division_values[row.name], axis=1)

# Display the modified DataFrame
print(Rev_Driver_age)
# Out:
#              Fatalities
# Age Group
# 0_to_16       74.666667
# 17_to_25     719.888889
# 26_to_39     446.857143
# 40_to_64     458.866667
# 65_to_74     202.888889
# 75_or_older  117.500000

# %%
#Creating a list for to use ina  subsequent procedure
List_age_group = cleaned_crash_data_1_df['Age Group'].unique()
List_age_group.sort()
List_age_group
# Out:
# array(['0_to_16', '17_to_25', '26_to_39', '40_to_64', '65_to_74',
#        '75_or_older'], dtype=object)

# %%
#Creating dataframe
Driver_Age_Fatalities = pd.DataFrame(Rev_Driver_age,index=List_age_group)

# Create a pie chart
plt.figure(figsize=(4, 4))
plt.pie(Driver_Age_Fatalities['Fatalities'], labels=Driver_Age_Fatalities.index, autopct='%1.1f%%', startangle=0)
plt.title('Fatalities by Drivers by Age Group (Normalised)')
plt.show()

# %%
Day_of_week = cleaned_crash_data_1_df.groupby(["Day of week"]).size()

Revised_driver_ages = pd.DataFrame(Day_of_week)
Revised_Day_of_week = Revised_driver_ages.rename(columns={ 0: 'Fatalities'})



# Define division values for each Age Group
gross_up_value = {
    'Weekday' : 5,
    'Weekend' : 2,

}

Revised_Day_of_week['Fatalities'] = Revised_Day_of_week.apply(lambda row: row['Fatalities'] / gross_up_value[row.name], axis=1)

Revised_Day_of_week
# Out:
#              Fatalities
# Day of week
# Weekday          6196.2
# Weekend         10856.5

# %%
#Generating a weeknd weekday list
List_day_of_week = cleaned_crash_data_1_df['Day of week'].unique()
List_day_of_week.sort()
List_day_of_week
# Out:
# array(['Weekday', 'Weekend'], dtype=object)

# %%
Revised_Day_of_week = pd.DataFrame(Revised_Day_of_week,index=List_day_of_week)

# Create a pie chart
plt.figure(figsize=(4, 4))
plt.pie(Revised_Day_of_week['Fatalities'], labels=Revised_Day_of_week.index, autopct='%1.1f%%', startangle=140)
plt.title('Fatalities by Drivers by Weekday / Weekend (Normalised)')
plt.show()

# %%
#road user dataframe

Road_user = cleaned_crash_data_1_df.groupby(["Road User"]).size()

Road_user = Road_user.sort_values(ascending=True)
Road_user
# Out:
# Road User
# Other/-9                           89
# Motorcycle pillion passenger      361
# Pedal cyclist                    1423
# Motorcycle rider                 6626
# Pedestrian                       8221
# Passenger                       12191
# Driver                          23783
# dtype: int64

# %%
#create bar chart
plt.barh(Road_user.index ,Road_user, align = "center")

#create the ticks 
plt.xticks(rotation= 90)

# Define x and y labels
plt.xlabel('Number of fatalities')
plt.ylabel('Road user fatality')
plt.title('Road user fatalities')

#Display bar chart
plt.show()

# %%
#Fatalities during Easter Period

Easter_period = cleaned_crash_data_1_df.groupby(["Easter Period"]).size()
Easter_period
# Out:
# Easter Period
# No     52425
# Yes      269
# dtype: int64

# %%
#Fatalities during Christmas period

Christmas_Period = cleaned_crash_data_1_df.groupby(["Christmas Period"]).size()
Christmas_Period
# Out:
# Christmas Period
# No     51067
# Yes     1627
# dtype: int64

# %%
#Get State data by size

State1 = cleaned_crash_data_1_df.groupby(["State"]).size()

Revised_State = pd.DataFrame(State1)
Revised_State2 = Revised_State.rename(columns={ 0: 'Fatalities'})


# Define division values for each Age Group taken from an API below
population = {
    'NSW' : 5312163,
    'VIC' : 5078193,
    'QLD' : 2514184,
    'WA' : 2059484,
    'SA' : 1345777,
    'NT' : 136828,
    'TAS' : 240342,
    'ACT' : 426704,

}
#fatalities per capita
Revised_State2['Fatalities'] = Revised_State2.apply(lambda row: row['Fatalities'] / population[row.name], axis=1)
#fatalities per capita (population)
Revised_State2
# Out:
#        Fatalities
# State
# ACT      0.001097
# NSW      0.003057
# NT       0.011898
# QLD      0.004168
# SA       0.003377
# TAS      0.006437
# VIC      0.002269
# WA       0.003042

# %%
#Creating a list for to use ina  subsequent procedure
List_state = cleaned_crash_data_1_df['State'].unique()
List_state.sort()
List_state
# Out:
# array(['ACT', 'NSW', 'NT', 'QLD', 'SA', 'TAS', 'VIC', 'WA'], dtype=object)

# %%
Revised_State2 = pd.DataFrame(Revised_State2,index=List_state)

# Create a pie chart
plt.figure(figsize=(4, 4))
plt.pie(Revised_State2['Fatalities'], labels=Revised_State2.index, autopct='%1.1f%%', startangle=140)
plt.title('Fatalities from crashes by state (Normalised) per capita (Population)')
plt.xlabel('State')
plt.show()

# %%
# Getting an API to get population

import requests
# List of Australian capital cities
australian_capital_cities = [
    'Canberra',
    'Sydney',
    'Melbourne',
    'Brisbane',
    'Perth',
    'Adelaide',
    'Hobart',
    'Darwin'
]

base_url = 'https://api.api-ninjas.com/v1/city?name={}'
for city in australian_capital_cities:
    api_url = base_url.format(city)
    response = requests.get(api_url, headers={'X-Api-Key': api_key})
    if response.status_code == requests.codes.ok:
        data = response.json()  # Assuming the response is in JSON format
        if data and isinstance(data, list) and len(data) > 0:
            city_data = data[0]  # Get the first item in the response
            population = city_data.get('population', 'Population data not available')
            print(f"{city}: Population - {population}")
        else:
            print(f"No data available for {city}")
    else:
        print(f"Error fetching data for {city}: {response.status_code} - {response.text}")
# Out:
# Canberra: Population - 426704
# Sydney: Population - 5312163
# Melbourne: Population - 5078193
# Brisbane: Population - 2514184
# Perth: Population - 2059484
# Adelaide: Population - 1345777
# Hobart: Population - 240342
# Darwin: Population - 136828

# %%
### Marianne's section 

### What time of day has the most fatal crashes in Victoria?

# Convert time column to "datetime" format for easy analysis
cleaned_crash_data_2_df['Time'] = pd.to_datetime(cleaned_crash_data_2_df['Time'], format='%H:%M')

# Extract the hour from the 'Time' column and create a new 'Hour' column
cleaned_crash_data_2_df['Hour'] = cleaned_crash_data_2_df['Time'].dt.hour

# Filter the data for rows where the State is 'VIC'
data_vic = cleaned_crash_data_2_df[cleaned_crash_data_2_df['State'] == 'VIC']

# Group by the 'Hour' column, count the number of crashes in each hour, and sort the result
hourly_crash_counts = data_vic.groupby('Hour').size().sort_values(ascending=False)

# Convert the series to a DataFrame for a nicer display
hourly_crash_counts_df = hourly_crash_counts.reset_index(name='Crash_Counts')
hourly_crash_counts_df.columns = ['Hour', 'Crash_Counts']

# Display the DataFrame
print(hourly_crash_counts_df)
# Out:
#     Hour  Crash_Counts
# 0     16           771
# 1     15           757
# 2     17           686
# 3     18           663
# 4     14           622
# 5     13           596
# 6     12           540
# 7     19           526
# 8     20           523
# 9     11           511
# 10    10           462
# 11    21           455
# 12    22           446
# 13    23           433
# 14     9           422
# 15     6           422
# 16     1           414
# 17     8           405
# 18     0           395
# 19     7           354
# 20     2           312
# 21     3           297
# 22     5           291
# 23     4           221
# C:\Users\theoc\AppData\Local\Temp\ipykernel_1212\2734062678.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# plot this as a bar graph

# Set the size
plt.figure(figsize=(10, 6))

# Create a bar chart
# 'Hour' is on the x-axis and 'Crash_Counts' is on the y-axis
plt.bar(hourly_crash_counts_df['Hour'], hourly_crash_counts_df['Crash_Counts'], color='skyblue')

# Add labels and title with updated information
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Fatal Crashes')
plt.title('Number of Fatal Crashes by Hour of the Day in Victoria from 1989 - 2021')

# Set x-ticks and x-tick labels to improve readability
plt.xticks(hourly_crash_counts_df['Hour'], [f'{hour}:00' for hour in hourly_crash_counts_df['Hour']])

# Optionally, add a grid
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Rotate the x-ticks for better visibility
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
# Count the occurrences of each gender in the 'Gender' column
gender_counts = data_vic['Gender'].value_counts()

# Display the counts
print(gender_counts)
# Out:
# Gender
# Male      8149
# Female    3375
# Name: count, dtype: int64

# %%
# Filter data for rows where 'Road User' is 'Driver'
driver_data = data_vic[data_vic['Road User'] == 'Driver']

# Count the amount of each gender in the 'Gender' column 
gender_counts_driver = driver_data['Gender'].value_counts()

# Create a bar chart
gender_counts_driver.plot(kind='bar', color=['blue', 'red'])

# Add labels and title
plt.xlabel('Gender')
plt.ylabel('Number of Crashes')
plt.title('Number of Crashes by Gender by Driver')

# Show the plot
plt.show()
